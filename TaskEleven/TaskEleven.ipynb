# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 8.4 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source="/content/traffic.mp4"
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 231MB/s]
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (1/844) /content/traffic.mp4: 384x640 33 cars, 3 trucks, 1209.2ms
# video 1/1 (2/844) /content/traffic.mp4: 384x640 30 cars, 3 trucks, 821.6ms
# video 1/1 (3/844) /content/traffic.mp4: 384x640 30 cars, 2 trucks, 812.0ms
# video 1/1 (4/844) /content/traffic.mp4: 384x640 30 cars, 3 trucks, 853.5ms
# video 1/1 (5/844) /content/traffic.mp4: 384x640 27 cars, 1 truck, 843.7ms
# video 1/1 (6/844) /content/traffic.mp4: 384x640 26 cars, 3 trucks, 792.0ms
# video 1/1 (7/844) /content/traffic.mp4: 384x640 27 cars, 2 trucks, 881.9ms
# video 1/1 (8/844) /content/traffic.mp4: 384x640 27 cars, 3 trucks, 863.8ms
# video 1/1 (9/844) /content/traffic.mp4: 384x640 26 cars, 3 trucks, 889.6ms
# video 1/1 (10/844) /content/traffic.mp4: 384x640 26 cars, 2 trucks, 840.5ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/traffic.avi"} -vcodec libx264 {"output.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !zip -r /content/taskeleven.zip /content/task
# Out:
#   adding: content/task/ (stored 0%)
#   adding: content/task/runs/ (stored 0%)
#   adding: content/task/runs/detect/ (stored 0%)
#   adding: content/task/runs/detect/predict/ (stored 0%)
#   adding: content/task/runs/detect/predict/traffic.avi (deflated 0%)
#   adding: content/task/output.mp4 (deflated 0%)
#   adding: content/task/yolov8m.pt (deflated 8%)
#   adding: content/task/traffic.mp4 (deflated 0%)

# %%
import shutil
shutil.copy("/content/taskeleven.zip","/content/drive/MyDrive/Taskeleven")
# Out:
# '/content/drive/MyDrive/Taskeleven'
